# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Importando un archivo Excel y convirtiendo las columnas Working_Year y Remote_Working_Ratio a tipo string

# %%
df = pd.read_excel("Datos.xlsx", sheet_name="Sheet1")
df["Working_Year"] = df["Working_Year"].astype("string")
df["Remote_Working_Ratio"] = df["Remote_Working_Ratio"].astype("string")
df
# Out:
#       Id Working_Year                 Designation Experience  \
# 0      1         2020              Data Scientist         MI
# 1      2         2020  Machine Learning Scientist         SE
# 2      3         2020           Big Data Engineer         SE
# 3      4         2020        Product Data Analyst         MI
# 4      5         2020   Machine Learning Engineer         SE
# ..   ...          ...                         ...        ...
# 602  603         2022               Data Engineer         SE
# 603  604         2022               Data Engineer         SE
# 604  605         2022                Data Analyst         SE
# 605  606         2022                Data Analyst         SE
# 606  607         2022                AI Scientist         MI
#
#     Employment_Status  Salary_In_Rupees Employee_Location Company_Location  \
# 0                  FT           6352272                DE               DE
# 1                  FT          20688070                JP               JP
# ...

# %% [markdown]
# Eliminando primera columna del dataframe, se debe tener en cuenta que axis = 1 es cuando se desea eliminar una columna y axis = 0 cuando se desea eliminar una fila y el inplace = True es para eliminar permanentemente la columna en el dataframe

# %%
df.drop("Id", axis=1, inplace=True)

# %% [markdown]
# Filtrar registros cuyo cargo sea Data Analyst y la experiencia sea MI usando variables

# %%
Cargo_Trabajador = "Data Analyst"
Experiencia_Trabajador = "MI"
Data_Designation = df[(df["Designation"] == Cargo_Trabajador) & (df["Experience"] == Experiencia_Trabajador)]
# El siguiente código permite observar todas las filas y columnas del dataframe
Data_Designation.iloc[:, :]
# Out:
#     Working_Year   Designation Experience Employment_Status  Salary_In_Rupees  \
# 14          2020  Data Analyst         MI                FT           6763408
# 15          2020  Data Analyst         MI                FT            636556
# 34          2020  Data Analyst         MI                FT           3720590
# 100         2021  Data Analyst         MI                FT           5967713
# 103         2021  Data Analyst         MI                FT           4933309
# 105         2021  Data Analyst         MI                FT           4099341
# 135         2021  Data Analyst         MI                FT           7161255
# 140         2021  Data Analyst         MI                FT          10741883
# 241         2021  Data Analyst         MI                FT           6365560
# 254         2021  Data Analyst         MI                FT           7399964
# 307         2022  Data Analyst         MI                FT           8455055
# ...

# %% [markdown]
# Filtrar registros cuyo cargo sea Data Analyst y trabaje en una empresa L

# %%
df[["Working_Year", "Designation", "Company_Size"]][(df["Designation"] == "Data Analyst") & (df["Company_Size"] == "L")]
# Out:
#     Working_Year   Designation Company_Size
# 5           2020  Data Analyst            L
# 14          2020  Data Analyst            L
# 15          2020  Data Analyst            L
# 34          2020  Data Analyst            L
# 51          2020  Data Analyst            L
# 100         2021  Data Analyst            L
# 103         2021  Data Analyst            L
# 105         2021  Data Analyst            L
# 140         2021  Data Analyst            L
# 233         2021  Data Analyst            L
# 241         2021  Data Analyst            L
# 254         2021  Data Analyst            L
# 261         2021  Data Analyst            L

# %% [markdown]
# Filtrar registros que contengan la palabra clave Engineer

# %%
df[df["Designation"].str.contains("Engineer")]
# Out:
#     Working_Year                Designation Experience Employment_Status  \
# 2           2020          Big Data Engineer         SE                FT
# 4           2020  Machine Learning Engineer         SE                FT
# 9           2020         Lead Data Engineer         SE                FT
# 16          2020              Data Engineer         EN                FT
# 17          2020          Big Data Engineer         SE                FT
# ..           ...                        ...        ...               ...
# 579         2022              Data Engineer         SE                FT
# 582         2022              Data Engineer         SE                FT
# 583         2022              Data Engineer         SE                FT
# 602         2022              Data Engineer         SE                FT
# 603         2022              Data Engineer         SE                FT
#
#      Salary_In_Rupees Employee_Location Company_Location Company_Size  \
# ...

# %% [markdown]
# Sueldos promedios por Designation

# %%
df.groupby("Designation").mean().round(2)
# Out:
#                                           Salary_In_Rupees
# Designation
# 3D Computer Vision Researcher                    430391.00
# AI Scientist                                    5262374.43
# Analytics Engineer                             13924662.75
# Applied Data Scientist                         13976780.80
# Applied Machine Learning Scientist             11304339.75
# BI Data Analyst                                 5948231.33
# Big Data Architect                              7933318.00
# Big Data Engineer                               4135545.25
# Business Data Analyst                           6102280.60
# Cloud Data Engineer                             9918099.50
# Computer Vision Engineer                        3534424.33
# Computer Vision Software Engineer               8374583.67
# Data Analyst                                    7391454.60
# Data Analytics Engineer                         5156044.00
# Data Analytics Lead                            32225648.00
# ...

# %% [markdown]
# Cantidad de trabajadores por Designation

# %%
df["Designation"].value_counts()
# Out:
# Data Scientist                              143
# Data Engineer                               132
# Data Analyst                                 97
# Machine Learning Engineer                    41
# Research Scientist                           16
# Data Science Manager                         12
# Data Architect                               11
# Big Data Engineer                             8
# Machine Learning Scientist                    8
# Principal Data Scientist                      7
# AI Scientist                                  7
# Data Science Consultant                       7
# Director of Data Science                      7
# Data Analytics Manager                        7
# ML Engineer                                   6
# Computer Vision Engineer                      6
# BI Data Analyst                               6
# Lead Data Engineer                            6
# Data Engineering Manager                      5
# Business Data Analyst                         5
# ...

# %%
df.groupby("Designation").sum().loc[["Data Analyst", "Lead Data Engineer"]].sort_values(by="Salary_In_Rupees", ascending=False)
# Out:
#                     Salary_In_Rupees
# Designation
# Data Analyst               716971096
# Lead Data Engineer          66706852

# %% [markdown]
# Usar la función agg para agrupar los registros por Designation y calcular el resultado min, max y la mediana de Salary_In_Rupees

# %%
df.groupby(["Designation"]).agg({"Salary_In_Rupees": ["min", "max", "median"]}).sort_values(by="Designation")
# Out:
#                                          Salary_In_Rupees            \
#                                                       min       max
# Designation
# 3D Computer Vision Researcher                      430391    430391
# AI Scientist                                       954834  15913900
# Analytics Engineer                               10741883  16335618
# Applied Data Scientist                            4315691  30236410
# Applied Machine Learning Scientist                2536278  33657899
# BI Data Analyst                                    737768  11935425
# Big Data Architect                                7933318   7933318
# Big Data Engineer                                  468028   9074663
# Business Data Analyst                             1467421  10741883
# Cloud Data Engineer                               7105079  12731120
# Computer Vision Engineer                           795695   9946188
# Computer Vision Software Engineer                 5569865  11935425
# ...

# %% [markdown]
# Agrupar por Employment_Status y calcular el Salary_In_Rupees max y min

# %%
df.groupby(["Employment_Status"]).agg({"Salary_In_Rupees": {"min", "max"}})
# Out:
#                   Salary_In_Rupees
#                                max      min
# Employment_Status
# CT                        33100912  2536278
# FL                         7956950   954834
# FT                        47741700   227489
# PT                         7956950   430391

# %% [markdown]
# Crear una función lambda que multiple por 2 aquellos Salary_In_Rupees que sean mayor a 15.000.000

# %%
df["Función"] = df.apply(lambda x: x["Salary_In_Rupees"] * 2 if x["Salary_In_Rupees"] > 15000000
else x["Salary_In_Rupees"], axis=1)
df
# Out:
#     Working_Year                 Designation Experience Employment_Status  \
# 0           2020              Data Scientist         MI                FT
# 1           2020  Machine Learning Scientist         SE                FT
# 2           2020           Big Data Engineer         SE                FT
# 3           2020        Product Data Analyst         MI                FT
# 4           2020   Machine Learning Engineer         SE                FT
# ..           ...                         ...        ...               ...
# 602         2022               Data Engineer         SE                FT
# 603         2022               Data Engineer         SE                FT
# 604         2022                Data Analyst         SE                FT
# 605         2022                Data Analyst         SE                FT
# 606         2022                AI Scientist         MI                FT
#
#      Salary_In_Rupees Employee_Location Company_Location Company_Size  \
# ...
